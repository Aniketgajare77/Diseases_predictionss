# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
liver=pd.read_csv('indian_liver_patient1.csv')

# %%
liver
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male              0.5               0.1                   500
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
liver.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
liver.tail()
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 578   60   Male              0.5               0.1                   500
# 579   40   Male              0.6               0.1                    98
# 580   52   Male              0.8               0.2                   245
# 581   31   Male              1.3               0.5                   184
# 582   38   Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# ...

# %%
liver.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'],
#       dtype='object')

# %% [markdown]
# Age: The age of the individual, represented as a numerical value. This feature captures the age of the patient, which can be an important factor in liver-related conditions.
#
# Gender: The gender of the individual, represented as a categorical variable (e.g., Male or Female). Gender may play a role in differentiating liver-related diseases, as some conditions are more prevalent in specific genders.
#
# Total_Bilirubin: Total bilirubin is a liver enzyme measured in the blood. Elevated levels of total bilirubin can indicate potential liver dysfunction or diseases.
#
# Direct_Bilirubin: Direct bilirubin is a fraction of the total bilirubin and can also indicate liver function or abnormalities.
#
# Alkaline_Phosphatase: Alkaline phosphatase is another liver enzyme, and its levels in the blood can provide insights into liver health.
#
# Alamine_Aminotransferase: This is an enzyme found in the liver, and elevated levels may indicate liver damage or disease.
#
# Aspartate_Aminotransferase: Like Alamine Aminotransferase, this enzyme is also found in the liver, and its levels can be indicative of liver health.
#
# Total_Protiens: Total proteins in the blood, including albumin and globulins, which are crucial for various bodily functions. Abnormal levels can point to liver-related issues.
#
# Albumin: Albumin is a protein synthesized by the liver. Its levels in the blood can reflect liver function.
#
# Albumin_and_Globulin_Ratio: The ratio of albumin to globulin levels, which can provide additional insights into liver health.
#
# Dataset: This is the target variable and typically represents the presence or absence of a liver disease or condition. It is a binary variable (0 or 1), with 0 indicating no liver disease and 1 indicating the presence of a liver-related condition.

# %%
liver.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Dataset                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %% [markdown]
# The dataset contains 583 entries and 11 columns.
#
# The following columns have null values:
#
# Albumin_and_Globulin_Ratio: 4 null values
#
# Data types of the columns: int64: Age, Alkaline_Phosphotase, Alamine_Aminotransferase, Aspartate_Aminotransferase, Dataset float64: Total_Bilirubin, Direct_Bilirubin, Total_Protiens, Albumin, Albumin_and_Globulin_Ratio object: Gender
#
# The memory usage of the dataset is approximately 50.2 KB.

# %%
liver.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# ...

# %%
liver.nunique()
# Out:
# Age                            72
# Gender                          2
# Total_Bilirubin               113
# Direct_Bilirubin               80
# Alkaline_Phosphotase          263
# Alamine_Aminotransferase      152
# Aspartate_Aminotransferase    177
# Total_Protiens                 58
# Albumin                        40
# Albumin_and_Globulin_Ratio     69
# Dataset                         2
# dtype: int64

# %%
liver['Dataset'].value_counts()
# Out:
# 1    416
# 2    167
# Name: Dataset, dtype: int64

# %%
liver['Dataset'] = liver['Dataset'].map({2:0,1:1})

# %%
liver['Dataset'].value_counts()
# Out:
# 1    416
# 0    167
# Name: Dataset, dtype: int64

# %% [markdown]
# # checking null values

# %%
liver.isnull().sum()/len(liver)*100
# Out:
# Age                           0.000000
# Gender                        0.000000
# Total_Bilirubin               0.000000
# Direct_Bilirubin              0.000000
# Alkaline_Phosphotase          0.000000
# Alamine_Aminotransferase      0.000000
# Aspartate_Aminotransferase    0.000000
# Total_Protiens                0.000000
# Albumin                       0.000000
# Albumin_and_Globulin_Ratio    0.686106
# Dataset                       0.000000
# dtype: float64

# %% [markdown]
# #### we have some null values but they are under 4% so we can drop this null values

# %%
liver.dropna(inplace=True)

# %%
liver.reset_index(drop=True,inplace=True)

# %%
liver.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %% [markdown]
# # now lets do some EDA

# %%
liver.groupby('Gender')['Dataset'].value_counts().plot(kind='bar',color=['r','y'])
# Out:
# <AxesSubplot:xlabel='Gender,Dataset'>

# %%
sns.pairplot(liver, hue='Dataset')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=liver.drop(columns=['Gender', 'Dataset']), orient='h')
plt.title("Box Plot for Numerical Variables")
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.countplot(x='Gender', data=liver)
plt.title("Gender Distribution")
plt.show()

# %%
plt.figure(figsize=(6, 5))
sns.countplot(x='Dataset', data=liver)
plt.title("Liver Disease Distribution")
plt.show()

# %%
num_col=liver.drop(['Gender'],axis=1)
num_col
# Out:
#      Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65              0.7               0.1                   187
# 1     62             10.9               5.5                   699
# 2     62              7.3               4.1                   490
# 3     58              1.0               0.4                   182
# 4     72              3.9               2.0                   195
# ..   ...              ...               ...                   ...
# 574   60              0.5               0.1                   500
# 575   40              0.6               0.1                    98
# 576   52              0.8               0.2                   245
# 577   31              1.3               0.5                   184
# 578   38              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                          16                          18             6.8
# ...

# %%
plt.figure(figsize= (15,15))
count=1
for i in num_col:
    
    plt.subplot(5,5,count)
    sns.distplot(num_col[i],color='green')
    count+=1
plt.show()

# %%
plt.figure(figsize=(12, 12))
count=1
for i in num_col:
    plt.subplot(5, 2, count)
    sns.violinplot(x='Dataset', y=i, data=liver, split=True)
    count+=1
    plt.title(f"{i} by Dataset")
    plt.tight_layout()

# %%
correlation_with_target = liver.corr()['Dataset'].drop('Dataset').sort_values(ascending=False)
plt.figure(figsize=(8, 6))
sns.barplot(x=correlation_with_target.index, y=correlation_with_target.values)
plt.xticks(rotation=45)
plt.title("Correlation with Target Variable 'Dataset'")
plt.show()

# %%
plt.figure(figsize=(12, 12))
sns.heatmap(liver.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # encoding

# %%
gender_mapping = {'Female': 0, 'Male': 1}

# %%
liver['Gender']=liver['Gender'].map(gender_mapping)

# %%
liver.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65       0              0.7               0.1                   187
# 1   62       1             10.9               5.5                   699
# 2   62       1              7.3               4.1                   490
# 3   58       1              1.0               0.4                   182
# 4   72       1              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
liver.dtypes
# Out:
# Age                             int64
# Gender                          int64
# Total_Bilirubin               float64
# Direct_Bilirubin              float64
# Alkaline_Phosphotase            int64
# Alamine_Aminotransferase        int64
# Aspartate_Aminotransferase      int64
# Total_Protiens                float64
# Albumin                       float64
# Albumin_and_Globulin_Ratio    float64
# Dataset                         int64
# dtype: object

# %%
X=liver.drop(['Dataset'],axis=1)

# %%
X
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65       0              0.7               0.1                   187
# 1     62       1             10.9               5.5                   699
# 2     62       1              7.3               4.1                   490
# 3     58       1              1.0               0.4                   182
# 4     72       1              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 574   60       1              0.5               0.1                   500
# 575   40       1              0.6               0.1                    98
# 576   52       1              0.8               0.2                   245
# 577   31       1              1.3               0.5                   184
# 578   38       1              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
y=liver['Dataset']
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 574    0
# 575    1
# 576    1
# 577    1
# 578    0
# Name: Dataset, Length: 579, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE(random_state=42)

# %%
X_sampled,y_sampled=sm.fit_resample(X,y)

# %%
liver['Dataset'].value_counts().plot(kind='bar')
plt.title("Before Oversampling")
plt.xlabel('Dataset')
plt.ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %%
y_sampled.value_counts().plot(kind='bar')
plt.title("After Oversampling")
plt.xlabel('Dataset')
plt.ylabel('counts')
# Out:
# Text(0, 0.5, 'counts')

# %% [markdown]
# # train models

# %%
from sklearn.model_selection import train_test_split

# %%
Xtrain,Xtest,ytrain,ytest=train_test_split(X_sampled,y_sampled,test_size=0.2,random_state=42)

# %%
Xtrain.shape,Xtest.shape
# Out:
# ((662, 10), (166, 10))

# %%
ytrain.shape,ytest.shape
# Out:
# ((662,), (166,))

# %% [markdown]
# # scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
se=StandardScaler()

# %%
Xtrain=se.fit_transform(Xtrain)
Xtest=se.fit_transform(Xtest)

# %% [markdown]
# # modeling`

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import AdaBoostClassifier
from xgboost import  XGBClassifier

from sklearn.metrics import accuracy_score,classification_report
from sklearn.metrics import roc_auc_score,roc_curve

# %%
knn=KNeighborsClassifier(n_neighbors=3)
lr=LogisticRegression()
dt=DecisionTreeClassifier()
ra=RandomForestClassifier()
ad=AdaBoostClassifier()
svm=SVC(probability=True)
gau=GaussianNB()
bag=BaggingClassifier()
Gr=GradientBoostingClassifier()
xg= XGBClassifier()

# %%
Training_score= []
Testing_score= []
def model_building(model):
    model.fit(Xtrain, ytrain)
    ytrain_pred= model.predict(Xtrain)
    ytest_pred= model.predict(Xtest)
    a= accuracy_score(ytrain, ytrain_pred)
    b= accuracy_score(ytest, ytest_pred)
    Training_score.append(a)
    Testing_score.append(b)
    print(model)
    print("Train Data\n", accuracy_score(ytrain,ytrain_pred))
    print("Test Data\n", accuracy_score(ytest,ytest_pred))

# %%
def roc_auc_curve(model):
    print("ROC-AUC CURVE:")
    ytest_prob= model.predict_proba(Xtest)
    fpr,tpr,thresh=roc_curve(ytest,ytest_prob[:,1])
    print('roc_score')
    roc_score=roc_auc_score(ytest,ytest_prob[:,1])
    
    sns.lineplot(x=fpr,y=tpr)
    sns.lineplot(x=[0.0,1.0],y=[0.0,1.0],color="red",linestyle="--")
    plt.xlabel("FPR")
    plt.ylabel("TPR")
    plt.title("ROC-AUC Curve")
    plt.show()
    print(roc_score)

# %%
from sklearn.metrics import log_loss

def calculate_logloss(model,ytest):
    print('log_loss:')
    ytest_prob= model.predict_proba(Xtest)

    logloss = log_loss(ytest, ytest_prob[:,-1])
    return logloss

# %%
model_building(knn)
roc_auc_curve(knn)
calculate_logloss(knn,ytest)
# Out:
# KNeighborsClassifier(n_neighbors=3)
# Train Data
#  0.8685800604229608
# Test Data
#  0.6927710843373494
# ROC-AUC CURVE:
# roc_score
# 0.7641892872695601
# log_loss:
# 3.0735860511281894

# %%
model_building(lr)
roc_auc_curve(lr)
calculate_logloss(lr,ytest)
# Out:
# LogisticRegression()
# Train Data
#  0.7311178247734139
# Test Data
#  0.6867469879518072
# ROC-AUC CURVE:
# roc_score
# 0.710262737697779
# log_loss:
# 0.5746606654056556

# %%
model_building(dt)
roc_auc_curve(dt)
calculate_logloss(dt,ytest)
# Out:
# DecisionTreeClassifier()
# Train Data
#  1.0
# Test Data
#  0.6506024096385542
# ROC-AUC CURVE:
# roc_score
# 0.6506024096385542
# log_loss:
# 12.067880850862315

# %%
model_building(ra)
roc_auc_curve(ra)
calculate_logloss(ra,ytest)
# Out:
# RandomForestClassifier()
# Train Data
#  1.0
# Test Data
#  0.7710843373493976
# ROC-AUC CURVE:
# roc_score
# 0.8696472637538104
# log_loss:
# 0.46142334765667153

# %%
model_building(ad)
roc_auc_curve(ad)

calculate_logloss(ad,ytest)
# Out:
# AdaBoostClassifier()
# Train Data
#  0.8353474320241692
# Test Data
#  0.6927710843373494
# ROC-AUC CURVE:
# roc_score
# 0.7652779793874291
# log_loss:
# 0.6395528989526655

# %%
model_building(svm)
roc_auc_curve(svm)
calculate_logloss(svm,ytest)
# Out:
# SVC(probability=True)
# Train Data
#  0.756797583081571
# Test Data
#  0.6987951807228916
# ROC-AUC CURVE:
# roc_score
# 0.7601974161707069
# log_loss:
# 0.5639165326609363

# %%
model_building(gau)
roc_auc_curve(gau)
calculate_logloss(gau,ytest)
# Out:
# GaussianNB()
# Train Data
#  0.6691842900302115
# Test Data
#  0.6927710843373494
# ROC-AUC CURVE:
# roc_score
# 0.748439541297721
# log_loss:
# 2.3907664445768533

# %%
model_building(bag)
roc_auc_curve(bag)
calculate_logloss(bag,ytest)
# Out:
# BaggingClassifier()
# Train Data
#  0.9848942598187311
# Test Data
#  0.7228915662650602
# ROC-AUC CURVE:
# roc_score
# 0.809188561474815
# log_loss:
# 0.5050826568848121

# %%
model_building(Gr)
roc_auc_curve(Gr)
calculate_logloss(Gr,ytest)
# Out:
# GradientBoostingClassifier()
# Train Data
#  0.9199395770392749
# Test Data
#  0.7409638554216867
# ROC-AUC CURVE:
# roc_score
# 0.7972129481782552
# log_loss:
# 0.5930407224189808

# %%
model_building(xg)
roc_auc_curve(xg)
calculate_logloss(xg,ytest)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)
# Train Data
#  1.0
# Test Data
#  0.7771084337349398
# ROC-AUC CURVE:
# roc_score
# 0.8854695892001742
# log_loss:
# 0.5707493307386632

# %%
knn_logloss=calculate_logloss(knn,ytest)
lr_logloss=calculate_logloss(lr,ytest)
dt_logloss=calculate_logloss(dt,ytest)
ra_logloss=calculate_logloss(ra,ytest)
ad_logloss=calculate_logloss(ad,ytest)
svm_logloss=calculate_logloss(svm,ytest)
gau_logloss=calculate_logloss(gau,ytest)
bag_logloss=calculate_logloss(bag,ytest)
Gr_logloss=calculate_logloss(Gr,ytest)
xg_logloss=calculate_logloss(xg,ytest)
# Out:
# log_loss:
# log_loss:
# log_loss:
# log_loss:
# log_loss:
# log_loss:
# log_loss:
# log_loss:
# log_loss:
# log_loss:

# %%
Models= ["k-Nearest Neighbors","Logistic Regression" ,"Decision Tree Classifier", "Random forest Classifier" ,
        "Ada-Boosting Classifier","svm","GaussianNB","Bagging Classifier", "Gradiant- Bossting Classifier","XGB"]

# %%
score_liver = pd.DataFrame({"Algorithms":Models,
                   "Training Score":Training_score,
                   "Testing Score":Testing_score,
                           'Log Loss': [knn_logloss, lr_logloss, dt_logloss, ra_logloss, ad_logloss,svm_logloss,gau_logloss,bag_logloss,Gr_logloss,xg_logloss]})

# %%
score_liver
# Out:
#                       Algorithms  Training Score  Testing Score   Log Loss
# 0            k-Nearest Neighbors        0.868580       0.692771   3.073586
# 1            Logistic Regression        0.731118       0.686747   0.574661
# 2       Decision Tree Classifier        1.000000       0.650602  12.067881
# 3       Random forest Classifier        1.000000       0.771084   0.461423
# 4        Ada-Boosting Classifier        0.835347       0.692771   0.639553
# 5                            svm        0.756798       0.698795   0.563917
# 6                     GaussianNB        0.669184       0.692771   2.390766
# 7             Bagging Classifier        0.984894       0.722892   0.505083
# 8  Gradiant- Bossting Classifier        0.919940       0.740964   0.593041
# 9                            XGB        1.000000       0.777108   0.570749

# %% [markdown]
# We consider two algorithm for the hyperparameter tunning are
#
# Random Forest Classifier:
#
# Training Score: 1.000000
# Testing Score: 0.771084
# Log Loss: 0.461423
#
# SVM:
#
# Training Score: 0.756798
# Testing Score: 0.698795
# Log Loss: 0.563917

# %% [markdown]
# # Random forest

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
random_forest_params = {
    'n_estimators': [25,50,75,100],
    'max_depth': [2, 3, 5, 10, 20],
    'min_samples_leaf': [5, 10, 20, 50, 100],
    'min_samples_split': [2, 5, 10],
    'criterion': ["gini", "entropy"],
    'max_features': ['auto', 'sqrt'],
    'bootstrap': [True, False]
}

# %%
ra_reg=RandomizedSearchCV(ra,param_distributions=random_forest_params,random_state=42,scoring='accuracy',cv=5,n_jobs=-1)

# %%
model_building(ra_reg)
roc_auc_curve(ra_reg)
calculate_logloss(ra_reg,ytest)
# Out:
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['gini', 'entropy'],
#                                         'max_depth': [2, 3, 5, 10, 20],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [5, 10, 20, 50,
#                                                              100],
#                                         'min_samples_split': [2, 5, 10],
#                                         'n_estimators': [25, 50, 75, 100]},
#                    random_state=42, scoring='accuracy')
# Train Data
#  0.945619335347432
# Test Data
#  0.7168674698795181
# ROC-AUC CURVE:
# roc_score
# 0.8323414138481636
# log_loss:
# 0.4964355272220825

# %% [markdown]
# # SVM

# %%
svm=SVC(probability=True)

# %%
param_grid = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto']
}

# %%
svm_reg = RandomizedSearchCV(svm, param_distributions=param_grid, n_iter=10, cv=5,n_jobs=-1)

# %%
model_building(svm_reg)
roc_auc_curve(svm_reg)
calculate_logloss(svm_reg,ytest)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(probability=True), n_jobs=-1,
#                    param_distributions={'C': [0.1, 1, 10],
#                                         'gamma': ['scale', 'auto'],
#                                         'kernel': ['linear', 'rbf', 'poly']})
# Train Data
#  0.7416918429003021
# Test Data
#  0.7469879518072289
# ROC-AUC CURVE:
# roc_score
# 0.7117869066627958
# log_loss:
# 0.5688660846624379

# %% [markdown]
# #### from these 2 algorithm we select SVM as our best parameter for this dataset

# %%
import pickle

# %%
pickle.dump(svm_reg,open("livermodel2.pkl",'wb'))

# %%
pickle.dump(se,open("liverscaling2.pkl",'wb'))
